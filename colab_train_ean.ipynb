# %% [markdown]
# # Evolutionary Abstraction Network GPU Training
#
# This notebook installs the project, verifies the runtime device, runs the unit tests, and launches a GPU-ready smoke training run.

# %% [markdown]
# ## 1. Clone the repository
# Change the URL if you use a different repository name.

# %%
# !git clone https://github.com/godsonj64/evolutionary-abstraction-network.git
# %cd evolutionary-abstraction-network

# %% [markdown]
# ## 2. Install dependencies

# %%
# !pip install -e .
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Verify GPU

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")

# %% [markdown]
# ## 4. Run tests

# %%
# !pytest -q

# %% [markdown]
# ## 5. Run GPU-ready training demo

# %%
# !python gpu_demo_train.py --steps 50 --batch-size 128 --latent-dim 128 --abstraction-dim 128 --hidden-dim 256 --initial-concepts 6 --max-concepts 16 --top-k 3

# %% [markdown]
# ## 6. Import model directly

# %%
from ean import EANConfig, EvolutionaryAbstractionNetwork
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = EvolutionaryAbstractionNetwork(EANConfig(input_dim=18, output_dim=3)).to(device)
x = torch.randn(4, 18, device=device)
out = model(x)
print(out["output"].shape, len(model.population))
